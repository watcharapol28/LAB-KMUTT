# %%
import numpy as np
import random
def objective(x, d):
    ans=0
    multi=1
    for j in range(d):
        multi *= np.cos(x[j] / np.sqrt(j + 1))
        
    for i in range(d):
        ans += ((x[i] * x[i]) / 4000)
        #print(i, ans)
    return ans - multi + 1

x=[0 for i in range(70)]


print(objective(x, 7))
print(objective(x, 70))
# Out:
# 0.0
# 0.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('./data/Covid.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('./data/Covid.csv')


iso = ['THA', 'JPN', 'SGP', 'IND', 'EGY', 'USA', 'GBR']
c = ['red', 'yellow', 'blue', 'green', 'pink', 'black', 'orange']
df = df[df['iso_code'].isin(iso)]
df = df[df['date']>='2021-01-01']
df = df[df['date']<='2022-06-30']

month = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

x = df.groupby('date').sum()

date = df['date'].unique()
newcases = [i for i in x['new_cases_per_million']]
deathcases = [i for i in x['new_deaths_per_million']]

len_date = len(df['date'].unique())//5
xtrick = [int(i * len_date) for i in range(6)]
#print(xtrick)

plt.figure(figsize=(16, 8), dpi=150)
plt.plot(date, newcases,label = 'New cases')
plt.plot(date, deathcases,label = 'New deaths')
plt.gca().set_xticks(xtrick)
#plt.tick_params(axis='both', which='minor', labelsize=12)
plt.xticks(fontsize=14, rotation=56)
plt.legend()
plt.show()
# Out:
# [0, 109, 218, 327, 436, 545]

# %%
df
# Out:
#        iso_code      continent       location        date  total_cases  \
# 58198       EGY         Africa          Egypt  2021-01-01     139471.0
# 58199       EGY         Africa          Egypt  2021-01-02     140878.0
# 58200       EGY         Africa          Egypt  2021-01-03     142187.0
# 58201       EGY         Africa          Egypt  2021-01-04     143464.0
# 58202       EGY         Africa          Egypt  2021-01-05     144583.0
# ...         ...            ...            ...         ...          ...
# 212076      USA  North America  United States  2022-06-26   87086707.0
# 212077      USA  North America  United States  2022-06-27   87246893.0
# 212078      USA  North America  United States  2022-06-28   87344729.0
# 212079      USA  North America  United States  2022-06-29   87534928.0
# 212080      USA  North America  United States  2022-06-30   87702287.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 58198      1409.0            1335.000        7687.0        56.0
# 58199      1407.0            1366.143        7741.0        54.0
# 58200      1309.0            1378.000        7805.0        64.0
# 58201      1277.0            1366.286        7863.0        58.0
# 58202      1119.0            1335.714        7918.0        55.0
# ...           ...                 ...           ...         ...
# 212076    22242.0          101695.286     1016401.0        20.0
# 212077   160186.0          110862.714     1016700.0       299.0
# 212078    97836.0          108936.000     1017276.0       576.0
# 212079   190199.0          109590.000     1018003.0       727.0
# 212080   167359.0          113736.571     1017727.0         NaN
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 58198                54.000  ...             0.2          50.1
# 58199                55.571  ...             0.2          50.1
# 58200                57.143  ...             0.2          50.1
# 58201                56.714  ...             0.2          50.1
# 58202                56.857  ...             0.2          50.1
# ...                     ...  ...             ...           ...
# 212076              343.143  ...            19.1          24.6
# 212077              372.286  ...            19.1          24.6
# 212078              389.429  ...            19.1          24.6
# 212079              371.143  ...            19.1          24.6
# 212080                  NaN  ...            19.1          24.6
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 58198                   89.827                        1.60            71.99
# 58199                   89.827                        1.60            71.99
# 58200                   89.827                        1.60            71.99
# 58201                   89.827                        1.60            71.99
# 58202                   89.827                        1.60            71.99
# ...                        ...                         ...              ...
# 212076                     NaN                        2.77            78.86
# 212077                     NaN                        2.77            78.86
# 212078                     NaN                        2.77            78.86
# 212079                     NaN                        2.77            78.86
# 212080                     NaN                        2.77            78.86
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 58198                     0.707                                   NaN
# 58199                     0.707                                   NaN
# 58200                     0.707                                   NaN
# 58201                     0.707                                   NaN
# 58202                     0.707                                   NaN
# ...                         ...                                   ...
# 212076                    0.926                             1132283.7
# 212077                    0.926                                   NaN
# 212078                    0.926                                   NaN
# 212079                    0.926                                   NaN
# 212080                    0.926                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 58198                           NaN               NaN
# 58199                           NaN               NaN
# 58200                           NaN               NaN
# 58201                           NaN               NaN
# 58202                           NaN               NaN
# ...                             ...               ...
# 212076                        15.32              6.46
# 212077                          NaN               NaN
# 212078                          NaN               NaN
# 212079                          NaN               NaN
# 212080                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 58198                                       NaN
# 58199                                       NaN
# 58200                                       NaN
# 58201                                       NaN
# 58202                                       NaN
# ...                                         ...
# 212076                              3359.915974
# 212077                                      NaN
# 212078                                      NaN
# 212079                                      NaN
# 212080                                      NaN
#
# [3822 rows x 67 columns]
