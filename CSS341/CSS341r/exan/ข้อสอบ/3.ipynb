# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/US-accidents.csv')
df
# Out:
#                ID  Severity                     Start_Time         City State  \
# 0       A-1381851         2  2021-09-15 18:07:32.000000000    Blue Bell    PA
# 1       A-2687499         2            2018-02-07 11:52:27    Cleveland    OH
# 2       A-1922192         2            2020-12-01 21:08:30    Fairfield    CA
# 3        A-911390         2  2021-06-13 12:13:00.000000000    Tehachapi    CA
# 4        A-103256         4            2016-05-20 23:38:45     Columbus    OH
# ...           ...       ...                            ...          ...   ...
# 499995  A-1619695         2  2021-01-15 02:37:30.000000000  Glastonbury    CT
# 499996   A-466164         2            2021-07-09 10:39:19     Columbia    SC
# 499997   A-220691         2            2017-07-25 15:09:02        Miami    FL
# 499998  A-1329176         2  2021-06-11 05:40:00.000000000    Dos Palos    CA
# 499999   A-131887         2            2016-06-29 14:07:48   Pleasanton    CA
#
# ...

# %%
df[df['Start_Time'].between_time('00:00','06:00')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 df[df['Start_Time'].between_time('00:00','06:00')]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:7852, in NDFrame.between_time(self, start_time, end_time, include_start, include_end, inclusive, axis)
#    7850 index = self._get_axis(axis)
#    7851 if not isinstance(index, DatetimeIndex):
# -> 7852     raise TypeError("Index must be DatetimeIndex")
#    7854 old_include_arg_used = (include_start != lib.no_default) or (
#    7855     include_end != lib.no_default
#    7856 )
#    7858 if old_include_arg_used and inclusive is not None:
#
# TypeError: Index must be DatetimeIndex

# %%
x = df['Start_Time'].dt.day_name()
x
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 x = df['Start_Time'].dt.day_name()
#       2 x
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
# ...

# %%
df['Start_Time']
# Out:
# 0         2021-09-15 18:07:32.000000000
# 1                   2018-02-07 11:52:27
# 2                   2020-12-01 21:08:30
# 3         2021-06-13 12:13:00.000000000
# 4                   2016-05-20 23:38:45
#                       ...
# 499995    2021-01-15 02:37:30.000000000
# 499996              2021-07-09 10:39:19
# 499997              2017-07-25 15:09:02
# 499998    2021-06-11 05:40:00.000000000
# 499999              2016-06-29 14:07:48
# Name: Start_Time, Length: 500000, dtype: object
