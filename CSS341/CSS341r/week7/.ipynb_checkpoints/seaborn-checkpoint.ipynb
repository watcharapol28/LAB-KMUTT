# %% [markdown]
# # <font color='blue'>Python Seaborn</font> for data visualization
# ### Chukiat Worasucheep (August 2022)

# %% [markdown]
# ## Importing / Installing packages

# %%
# To install seaborn, type "pip install seaborn" to the anaconda or cmd terminal
#
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 6>()
#       4 import pandas as pd
#       5 import matplotlib.pyplot as plt
# ----> 6 import seaborn as sns
#       7 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'seaborn'

# %% [markdown]
# ## 1. Load raw data and investigate its basic information

# %%
df = pd.read_csv("tips.csv")
df.info()
df.describe()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## 1. Line Plots

# %%
# Relation between total bill and tip
sns.lineplot(x='total_bill', y='tip', data=df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# Relation between size and tip
sns.lineplot(x='size', y='tip', data=df, ci=None)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
# Relation between size and tip
sns.lineplot(x='size', y='tip', data=df)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
# changing the size of plot, hue, style, and markers
#
plt.figure(figsize=(7, 5))
sns.lineplot(x='size', y='tip', data=df, hue='sex', style='sex', markers=True)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
# different hue and style
#
sns.lineplot(x='size', y='tip', data=df, hue='sex', style='smoker', ci=False)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %% [markdown]
# ### LinePlot Documentation
# https://seaborn.pydata.org/generated/seaborn.lineplot.html

# %% [markdown]
# ## 3. Bar Plots
# #### Show point estimates and confidence intervals as rectangular bars.

# %%
# plot relation between tip and day
#
sns.barplot(x='day', y='tip', data=df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
# plot relation between tip and day group by smoker
#
sns.barplot(x='day', y='tip', data=df, hue='smoker', ci=False)

#sns.catplot(x='day', y='tip', data=df, hue='smoker', ci=False, kind='bar')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
# count the number of smoker and non-smoker in each day
#
sns.catplot(x='day', data=df, hue='size', ci=False, kind='count')

# %%
# horizontal bar with color setting
#
sns.barplot(x='tip', y='day', data=df, hue='size', ci=False, orient='h', color='green')

# https://htmlcolorcodes.com/color-picker/
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %% [markdown]
# ## 4. Pie charts
#
# #### A pie chart is a circular statistical graphic, which is divided into slices to illustrate numerical proportion. In a pie chart, the arc length of each slice is proportional to the quantity it represents.

# %%
import matplotlib.pyplot as plt
import seaborn

# declare data
data = [60, 22, 40, 41, 32]
keys = ['Finance', 'Accounting', 'Psychology', 'Marketing', 'Laws']

# define Seaborn color palette to use
palette_color = seaborn.color_palette('Set2')  # Set2, paster

# plotting data on chart
plt.pie(data, labels=keys, colors=palette_color,
        explode=[0, 0, 0, 0, 0.3], autopct='%.0f%%')

# displaying chart
plt.title('Students taking elective courses')
plt.show()

# %% [markdown]
# ## 5. Distribution plots
# While histogram can visualize distribution of one variable, seaborn offers several different approaches to visualizing the multivariate distributions of data.

# %% [markdown]
# ### Recall of matplotlib's histogram

# %%
plt.hist(df['tip'], bins=20)    # The distribution plot of tip by matplotlib
# Out:
# (array([14., 27., 55., 24., 41., 25., 20.,  7., 13.,  6.,  4.,  1.,  4.,
#          0.,  1.,  0.,  0.,  1.,  0.,  1.]),
#  array([ 1.  ,  1.45,  1.9 ,  2.35,  2.8 ,  3.25,  3.7 ,  4.15,  4.6 ,
#          5.05,  5.5 ,  5.95,  6.4 ,  6.85,  7.3 ,  7.75,  8.2 ,  8.65,
#          9.1 ,  9.55, 10.  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ## Seaborn Distribution plots
#
#
# #### Flexibly plot a univariate distribution of observations.
# This function provides access to several approaches for visualizing the univariate or bivariate distribution of data. The <font color='blue'>kind</font> parameter selects the approach to use:
#
# <li>histplot() (with kind="hist"; the default) A hitogram plot of a univariate data.
#
# <li>kdeplot() (with kde=True) A kernel density estimate (KDE) plot for visualizing the distribution of observations in a dataset, analagous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions.
#
# <li>ecdfplot() (with kind="ecdf") Empirical cumulative distribition function

# %% [markdown]
# ### Histogram

# %%
# histogram with seaborn's displot()
#
sns.displot(df['tip'], bins=20)    # The histogram (default kind) plot of tip with seaborn

# %% [markdown]
# ### KDE (Kernel Density Estimate) plot
# KDE plot smooths the observations with a Gaussian kernel, producing a continuous density estimate:

# %%
# Kernel Density Estimate plot
#
sns.displot(df['tip'], kind='kde')

# %%
# Kernel Density Estimate plot, with hue=smoker grouping
#
sns.displot(df, x='tip', hue='smoker', kind='kde') # , fill=True)

# %%
# kde plot with stacking smoker grouping (like area chart)
#
sns.displot(df, x='tip', hue='smoker', kind='kde', multiple='stack')

# %%
# histogram together with kernel density estimate and mean value
#
sns.displot(df['tip'], bins=20, kde=True) # histogram with KDE

# add axis verticle line (axvline)
#
plt.axvline(df['tip'].mean(), 0.3, 0.7, color='red')  # ploting the mean value in red

# %% [markdown]
# ### ECDF (Empirical Cumulative Distribution Function) plot
# ECDF plot an estimate of the cumulative distribution function that generated the points in the sample. It smooths an increasing curve through each datapoint such that the height of the curve reflects the proportion of observations with a smaller value:

# %%
# Empirical Cumulative Distribution Function (ฟังก์ชันการกระจายสะสมค่าจากการทดลอง)
#
sns.displot(df['tip'], kind='ecdf')

# %%
# Empirical Cumulative Distribution Function with smoker grouping
#
sns.displot(df, x='tip', kind='ecdf', hue='sex')

# %% [markdown]
# ## 6. Box Plots
# #### Draw a box plot to show distributions with respect to categories.

# %%
sns.boxplot(x='size', y='tip', data=df)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
# grouping with sex
#
sns.boxplot(x='size', y='tip', data=df, hue='sex')
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %% [markdown]
# ### More on Boxplots here:
# https://seaborn.pydata.org/generated/seaborn.boxplot.html#seaborn.boxplot

# %% [markdown]
# ## 8. ScatterPlots
# #### Draw a scatter plot with possibility of several semantic groupings.

# %%
df.columns   # attributes of data
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# Relationship between total bill and tip
#
sns.scatterplot(x='total_bill', y='tip', data=df, color='green')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# total bill and tip with sex
#
sns.scatterplot(x='total_bill', y='tip', data=df, hue='sex', style='smoker')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# total bill and tip with scatter size
#
plt.figure(figsize=(10,6))
sns.scatterplot(x='total_bill', y='tip', data=df, hue='sex', style='sex', 
                size='tip', sizes=(50, 200))
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## 9. Heat map
# #### Draw a heat map to see correlation coefficients of data

# %%
car_crashes = pd.read_csv('car_crashes.csv')
car_crashes.info()
car_crashes.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      51 non-null     int64
#  1   total           51 non-null     float64
#  2   speeding        51 non-null     float64
#  3   alcohol         51 non-null     float64
#  4   not_distracted  51 non-null     float64
#  5   no_previous     51 non-null     float64
#  6   ins_premium     51 non-null     float64
#  7   ins_losses      51 non-null     float64
#  8   abbrev          51 non-null     object
# dtypes: float64(7), int64(1), object(1)
# memory usage: 3.7+ KB
#    Unnamed: 0  total  speeding  alcohol  not_distracted  no_previous  \
# 0           0   18.8     7.332    5.640          18.048       15.040
# 1           1   18.1     7.421    4.525          16.290       17.014
# 2           2   18.6     6.510    5.208          15.624       17.856
# ...

# %%
corr = car_crashes.corr()
print(corr)
# Out:
#                 Unnamed: 0     total  speeding   alcohol  not_distracted  \
# Unnamed: 0        1.000000  0.058292  0.082048  0.157353        0.025438
# total             0.058292  1.000000  0.611548  0.852613        0.827560
# speeding          0.082048  0.611548  1.000000  0.669719        0.588010
# alcohol           0.157353  0.852613  0.669719  1.000000        0.732816
# not_distracted    0.025438  0.827560  0.588010  0.732816        1.000000
# no_previous      -0.022890  0.956179  0.571976  0.783520        0.747307
# ins_premium      -0.198943 -0.199702 -0.077675 -0.170612       -0.174856
# ins_losses       -0.140306 -0.036011 -0.065928 -0.112547       -0.075970
#
#                 no_previous  ins_premium  ins_losses
# Unnamed: 0        -0.022890    -0.198943   -0.140306
# total              0.956179    -0.199702   -0.036011
# speeding           0.571976    -0.077675   -0.065928
# alcohol            0.783520    -0.170612   -0.112547
# ...

# %%
plt.figure(figsize=(12, 6))

sns.heatmap(corr, annot=True, linewidths=1, cmap='coolwarm')

# colormap https://matplotlib.org/stable/tutorials/colors/colormaps.html
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 10. Pairplots
# #### Plot pairwise relationships in a dataset.

# %%
sns.pairplot(df)

# %%
sns.pairplot(df[['total_bill', 'tip']])   # running on specific columns

# %%
sns.pairplot(df, hue='sex')  # categorized with sex

# %%
# categorized with sex and kind=reg (reg is regression)
#
sns.pairplot(df, hue='sex', kind='reg')

# %% [markdown]
# ### More on Pairplots:
# https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %% [markdown]
# ## 11. JoinPlots
# #### Draw a plot of two variables with bivariate and univariate graphs.

# %%
# tip vs size relationship
#
sns.jointplot(x='tip', y='total_bill', data=df)

# %%
# tip vs size relationship with regression estimate on a larger chart
# kind='reg' to add a linear regression fit (using regplot()) and univariate KDE curves:
#
sns.jointplot(x='tip', y='total_bill', data=df, kind='reg', height=9)

# %%
# tip vs size relationship with kde type and different sex colorsb
#
sns.jointplot(x='tip', y='total_bill', data=df, height=8, kind='kde', hue='sex')

# %% [markdown]
# ## 12. FacetGrid
#
# FacetGrid visualizes the distribution of a variable or the relationship between multiple variables separately within subsets of your dataset.
# <li>
#     The variables should be categorical and the data at each level of the variable will be used for a facet along that axis.
#  <li>A FacetGrid can be drawn with up to three dimensions: row, col, and hue.

# %%
# univariate, use time to differentiate by col
#
g = sns.FacetGrid(df, col='time')
g.map(sns.histplot, 'tip')

# %%
# bivariate, use sex and smoker to differentiate cols and hues
#
g = sns.FacetGrid(df, col='sex', hue='smoker')
g.map(sns.scatterplot, 'total_bill', 'tip', alpha=.7)
plt.figure(figsize=(12,7))
g.add_legend()

# %%
# enlarge the figure and font size
#
sns.set(font_scale=1.5)
g = sns.FacetGrid(df, col='sex', hue='smoker', height=6)
g.map(sns.scatterplot, 'total_bill', 'tip', alpha=.7)
plt.figure(figsize=(12,7))
g.add_legend()

# %% [markdown]
# ### More on JoinPlots:
# https://seaborn.pydata.org/generated/seaborn.jointplot.html

# %% [markdown]
# ## 13. Matplotlib SubPlots

# %%
# Set up the matplotlib figure
#
fig, axes = plt.subplots(2, 2, figsize=(12, 7))

#plot1
sns.lineplot(ax=axes[0, 0], x='total_bill', y='tip', data=df)

#plot2
sns.boxplot(ax=axes[0, 1], x='size', y='tip', data=df)

#plot3
sns.scatterplot(ax=axes[1, 0], x='total_bill', y='tip', data=df)

#plot4
sns.barplot(ax=axes[1, 1], x='size', y='tip', data=df)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %% [markdown]
# ## 14. Save the charts into storage

# %%
g.savefig('my_facetgrid.jpg', format='jpeg', dpi=200)
fig.savefig('my_subplot.jpg', format='jpeg', dpi=200)

# !dir/od
# Out:
#  Volume in drive D is Data
#  Volume Serial Number is A234-7DEE
#
#  Directory of D:\Desktop\tmp\Data visualization
#
# 08/07/2019  01:21 PM            14,436 seattletemps.csv
# 04/01/2020  05:51 PM         2,660,439 anaconda_guide.docx
# 04/01/2020  05:51 PM           618,498 anconda_create_env_guide.docx
# 04/04/2020  09:19 AM         5,048,969 IntroPythonProgrammingUpdated.pdf
# 04/04/2020  11:40 AM             9,729 tips.csv
# 04/05/2022  05:39 PM             3,049 car_crashes.csv
# 09/08/2022  11:06 AM         7,977,741 DS06 Data visualization.pptx
# 09/08/2022  11:06 AM    <DIR>          .ipynb_checkpoints
# 09/08/2022  11:55 AM           963,088 matplotlib.ipynb
# 09/08/2022  02:40 PM           152,149 seaborn.ipynb
# 09/08/2022  02:40 PM    <DIR>          ..
# 09/08/2022  02:40 PM    <DIR>          .
# 09/08/2022  02:40 PM           214,099 my_facetgrid.jpg
# 09/08/2022  02:40 PM           292,553 my_subplot.jpg
#               11 File(s)     17,954,750 bytes
# ...

# %% [markdown]
# ## This is the end of demonstration.
