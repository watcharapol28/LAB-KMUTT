# %% [markdown]
# # <font color='blue'>Python Matplotlib</font> for data visualization
# ### Chukiat Worasucheep (August 2022)

# %%
#import warnings
#warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Line Chart

# %%
x = [-2, -1,  0, 1, 2]
y = [ 3,  5, -1, 1, 2]
z = [-4,  4,  2, 0, 3]

plt.plot(x, y)
plt.show()

plt.plot(x, z)
plt.show()

# %% [markdown]
# ### Show grid, change marker type, and add some text

# %%
x = [-2, -1,  0, 1, 2]
y = [ -3, -1, 1, 3, 0]
z = [3, 2.5, -1, -2, 2]

plt.plot(x, y)        # plot x and y using default line style and color
plt.plot(x, z, 'ro')  # plot x and y using red circle markers

# set range of both axises


# display some text on the chart


plt.show()

# %% [markdown]
# More about marker types: https://matplotlib.org/stable/api/markers_api.html
#
# ![image.png](attachment:image.png)

# %% [markdown]
# More info: <a href='https://matplotlib.org/3.1.1/gallery/showcase/anatomy.html'>Anatomy of matplotlib's plot<a>
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# https://matplotlib.org/3.2.2/gallery/color/named_colors.html
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h3>More info: official <a href="https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html">web of matplotlib.pyplot.plot<a>

# %%
df = pd.read_csv('seattletemps.csv')
print('The shape of our features is:', df.shape) #tells the number of rows and columns
df.describe()
# Out:
# The shape of our features is: (348, 12)
#          year       month         day      temp_2      temp_1     average  \
# count   348.0  348.000000  348.000000  348.000000  348.000000  348.000000
# mean   2016.0    6.477011   15.514368   62.652299   62.701149   59.760632
# std       0.0    3.498380    8.772982   12.165398   12.120542   10.527306
# min    2016.0    1.000000    1.000000   35.000000   35.000000   45.100000
# 25%    2016.0    3.000000    8.000000   54.000000   54.000000   49.975000
# 50%    2016.0    6.000000   15.000000   62.500000   62.500000   58.200000
# 75%    2016.0   10.000000   23.000000   71.000000   71.000000   69.025000
# max    2016.0   12.000000   31.000000  117.000000  117.000000   77.400000
#
#            actual  forecast_noaa  forecast_acc  forecast_under      friend
# count  348.000000     348.000000    348.000000      348.000000  348.000000
# mean    62.543103      57.238506     62.373563       59.772989   60.034483
# ...

# %%
df.head() #Viewing the first 5 lines
# Out:
#    year  month  day  week  temp_2  temp_1  average  actual  forecast_noaa  \
# 0  2016      1    1   Fri      45      45     45.6      45             43
# 1  2016      1    2   Sat      44      45     45.7      44             41
# 2  2016      1    3   Sun      45      44     45.8      41             43
# 3  2016      1    4   Mon      44      41     45.9      40             44
# 4  2016      1    5  Tues      41      40     46.0      44             46
#
#    forecast_acc  forecast_under  friend
# 0            50              44      29
# 1            50              44      61
# 2            46              47      56
# 3            48              46      53
# 4            46              46      41

# %%
# plot the average actual, and forecast using red, green, and blue color
plt.plot(df.average, label='average', color='red')
plt.plot(df.actual,  label='actual',  color='green')
plt.plot(df.forecast_noaa,  label='forecast_noaa')

# set chart title and axis labels too
plt.title('Seattle Temperature')
plt.xlabel('day')
plt.ylabel('fahrenheit')

# show chart legends too
plt.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# change font size of all components in the plot and chart size to 12x8
# plt.rcParams.update(.......)
# plt.figure(.........)

plt.plot(df.average, label='average', color='red')
plt.plot(df.actual,  label='actual',  color='green')
plt.plot(df.forecast_noaa,  label='forecast_noaa')

plt.title('Seattle Temperature', fontsize=20, color='darkblue')
plt.xlabel('day')
plt.ylabel('fahrenheit')

# move the legend to upper left corner, and show grid
plt.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# review

import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 4 * np.pi, 0.1)
y = np.sin(x)
z = np.cos(x)

plt.figure(figsize=(10, 5))

plt.plot(x, y)
plt.plot(x, z)

plt.title('Sine and Cosine Waves')
plt.xlabel('x')
plt.ylabel('y = sin(x), z = cos(x)')

# show legends of all with one command
plt.legend(['sin(x)', 'cos(x)'], loc ="upper right") #loc = position legend
plt.grid(True) #ตารางพื่นหลัง
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
# Data to plot
names = 'Python', 'C++', 'Ruby', 'Java'
vals  = [215, 130, 190, 210]

colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

plt.figure(figsize=(7,7))
plt.pie(vals, labels=names, colors=colors)

# then set radius size=1.5,add shadow, explode some pieces out,
# set start angle=90 (horz), and show percentage in yy.x% format

plt.show()

# %% [markdown]
# ## Bar Chart

# %%
import numpy as np
import matplotlib.pyplot as plt

# creating the dataset
data = {'C':20, 'C++':15, 'Java':30, 'Python':35}
courses = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize = (10, 5))

# creating the bar plot of the value for each course
# with color=green and width=0.5
plt.bar(courses, values, color='green', width=0.5)

plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")

# add labels on top of the bars
for index,data in enumerate(values):
    plt.text(x=index, y=data+0.5 , s=f"{data}")

plt.show()

# %%
# horizontal bar chart using barh() function
import numpy as np
import matplotlib.pyplot as plt
  
# creating the dataset
data = {'C':20, 'C++':15, 'Java':30, 'Python':35}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the horizontal bar plot with color='turquoise'
#plt.barh()
 
plt.xlabel("No. of students enrolled")
plt.ylabel("Courses offered")
plt.title("Students enrolled in different courses", 
          fontsize=20, color='Darkblue')

# switch x and y locations
for index,data in enumerate(values):
    plt.text(y=index , x=data+0.5 , s=f"{data}")

plt.show()

# %% [markdown]
# ## Stacked bar chart
# For example......
# ![image.png](attachment:image.png)

# %%
# importing package
import matplotlib.pyplot as plt
import numpy as np
 
# create data
x = ['A', 'B', 'C', 'D']   # team
y1 = np.array([10, 20, 10, 30])
y2 = np.array([20, 25, 15, 25])
y3 = np.array([12, 15, 19, 6])
 
# plot bars in stack manner
fig = plt.figure(figsize = (9, 5))
plt.bar(x, y1, color='y')
plt.bar(x, y2, bottom=y1, color='r')
plt.bar(x, y3, bottom=y1+y2, color='b')

plt.xlabel('Teams')
plt.ylabel('Score')
plt.legend(['1st Round', 'Semi-final', 'Final'])
plt.title('Scores by Teams in 4 Rounds')

plt.show()

# %% [markdown]
# ## Side-by-side Bar charts

# %%
import numpy as np
import matplotlib.pyplot as plt

men_means   = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std     = [4, 9, 7, 4, 8]
women_std   = [3, 5, 10, 3, 9]

ind = np.arange(len(men_means))  # the x locations for the groups
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind - width/2, men_means, width, yerr=men_std,
                color='SkyBlue', label='Men')
rects2 = ax.bar(ind + width/2, women_means, width, yerr=women_std,
                color='IndianRed', label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Risks')
ax.set_title('Risks by group and gender')
ax.set_xticks(ind)
ax.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5'))
ax.legend()

def autolabel(rects, xpos='center'):
    """
    Attach a text label above each bar in *rects*, displaying its height.
    *xpos* indicates which side to place the text w.r.t. the center of the bar.
    It can be one of the following {'center', 'right', 'left'}.
    """
    
    xpos = xpos.lower()  # normalize the case of the parameter
    ha = {'center': 'center', 'right': 'left', 'left': 'right'}
    offset = {'center': 0.5, 'right': 0.57, 'left': 0.43}
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width() * offset[xpos], 1.01 * height,
                '{}'.format(height), ha=ha[xpos], va='bottom')

autolabel(rects1, "left")
autolabel(rects2, "right")
            
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
# https://pythonspot.com/matplotlib-scatterplot/

# Create data
N = 40
x = np.random.rand(N)
y = np.random.rand(N)

# Plot
plt.scatter(x, y)
plt.title('Scatter plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
df = pd.read_csv('seattletemps.csv')

plt.figure(figsize=(8, 6))
plt.scatter(x=df.actual, y=df.average, c='green')
plt.title('Seattle Temperature')
plt.xlabel('Actual (F)')
plt.ylabel('Average (F)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Box Plot

# %%
np.random.seed(10)
data = np.random.normal(100, 20, 200)
 
plt.boxplot(data)
plt.show()

# %%
np.random.seed(123)      # set arbitrarily for reproducibility
d1 = np.random.normal(100, 10, 100)
d2 = np.random.normal(80, 20, 100)
d3 = np.random.normal(60, 30, 100)
d4 = np.random.normal(40, 40, 100)
 
plt.figure(figsize=(7, 5))
plt.boxplot([d1, d2, d3, d4], labels=['first', 'second', 'third', 'fourth'])
plt.show()

plt.figure(figsize=(7, 5))
plt.boxplot([d1, d2, d3, d4], labels=['first', 'second', 'third', 'fourth'], vert=False)
plt.show()

# %% [markdown]
# ## Subplots

# %%
# subplot(nrows, ncols, index, **kwargs)
# Three integers (nrows, ncols, index). The subplot will take 
# the index position on a grid with nrows rows and ncols columns. 
# index starts at 1 in the upper left corner and increases to the right. 

x = np.linspace(1, 10, 20)   # create 20 x data between [1, 10]

plt.figure(figsize=(10, 4))
plt.title('Subplots')

plt.subplot(1, 2, 1)
plt.plot(x, x**2, 'o-')
plt.title('Left subplot')
plt.xlabel('X')
plt.ylabel('X^2')

plt.subplot(1, 2, 2)
plt.plot(x, 1/x, '.-')
plt.title('Right subplot')
plt.xlabel('X')
plt.ylabel('1/X')

# set the spacing between subplots
plt.subplots_adjust(left=0.05,   right=0.95, 
                    bottom=0, top=1, 
                    wspace=0.2, hspace=0.1)  # They are the fractions of the width and height of the figure.

plt.show()

# %% [markdown]
# ### There are several ways to control the subplots. Please further study at
#
# <p>
#     https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplots_demo.html

# %%
x = np.linspace(1, 10, 20)   # create 20 x data between [1, 10]
y = x*x

fig, axs = plt.subplots(2)
fig.suptitle('Vertically stacked subplots')

axs[0].plot(x, y)
axs[1].plot(x, -y)

# %%
x = np.linspace(1, 10, 20)   # create 20 x data between [1, 10]
y = x*x

fig, (ax0, ax1) = plt.subplots(1, 2)
fig.suptitle('Horizontally stacked subplots')

ax0.plot(x, y)
ax1.plot(x, -y)

# %%
fig, axs = plt.subplots(2, 2, figsize=(9,7))
fig.suptitle('2x2 Multitype subplots')

y = x*x
axs[0][0].plot(x, y)
axs[0][1].plot(x, -y)

np.random.seed(123)      # set arbitrarily for reproducibility
d1 = np.random.normal(100, 10, 100)
d2 = np.random.normal(80, 20, 100)
axs[1][0].boxplot([d1, d2], labels=['first', 'second'])

df = pd.read_csv('seattletemps.csv')
df = df.iloc[0:100:3,]
axs[1][1].scatter(x=df.actual, y=df.average, c='green')
axs[1][1].grid(True)

plt.show()

# %% [markdown]
# ## This is the end of demonstration.
