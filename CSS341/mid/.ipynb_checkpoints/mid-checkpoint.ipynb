# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data1/sales.csv")

# %%
df2 = df[df['item_cnt_day'] >= 0]
df2 = df2[df2['item_price'] >= 0]
df1_count = df['item_cnt_day'].count()
df2.to_csv("data1/sales.csv", index = False)
df = df2

# %%
display(df)
df_dropdone = pd.read_csv("data1/sales.csv")
display(df_dropdone)
df2_count = df_dropdone['item_cnt_day'].count()
print("Data begin :", df1_count, "\t\tData processed :", df2_count)
print("Drop",df1_count - df2_count, "data done.")
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        06.01.2013               0       25     2554     1709.05
# 3        15.01.2013               0       25     2555     1099.00
# 4        10.01.2013               0       25     2564      349.00
# ...             ...             ...      ...      ...         ...
# 2928487  10.10.2015              33       25     7409      299.00
# 2928488  09.10.2015              33       25     7460      299.00
# 2928489  14.10.2015              33       25     7459      349.00
# 2928490  22.10.2015              33       25     7440      299.00
# 2928491  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                 1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 2928487           1.0
# 2928488           1.0
# 2928489           1.0
# 2928490           1.0
# 2928491           1.0
#
# [2928492 rows x 6 columns]
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        06.01.2013               0       25     2554     1709.05
# 3        15.01.2013               0       25     2555     1099.00
# 4        10.01.2013               0       25     2564      349.00
# ...             ...             ...      ...      ...         ...
# 2928487  10.10.2015              33       25     7409      299.00
# 2928488  09.10.2015              33       25     7460      299.00
# 2928489  14.10.2015              33       25     7459      349.00
# 2928490  22.10.2015              33       25     7440      299.00
# 2928491  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                 1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 2928487           1.0
# 2928488           1.0
# 2928489           1.0
# 2928490           1.0
# 2928491           1.0
#
# [2928492 rows x 6 columns]
# Data begin : 2928492 		Data processed : 2928492
# Drop 0 data done.

# %%
#9
file = "data2/tx201"
tx = pd.DataFrame()
for i in range(6):
  path = file + str(i) + ".csv"
  tx_read = pd.read_csv(path)
  tx = tx.merge(tx_read, how = 'outer')
display(tx)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Input In [13], in <cell line: 4>()
#       5   path = file + str(i) + ".csv"
#       6   tx_read = pd.read_csv(path)
# ----> 7   tx = tx.merge(tx_read, how = 'outer')
#       8 display(tx)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:9351, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9332 @Substitution("")
#    9333 @Appender(_merge_doc, indents=2)
#    9334 def merge(
#    (...)
#    9347     validate: str | None = None,
#    9348 ) -> DataFrame:
#    9349     from pandas.core.reshape.merge import merge
# -> 9351     return merge(
#    9352         self,
#    9353         right,
#    9354         how=how,
#    9355         on=on,
#    9356         left_on=left_on,
#    9357         right_on=right_on,
#    9358         left_index=left_index,
#    9359         right_index=right_index,
#    9360         sort=sort,
#    9361         suffixes=suffixes,
#    9362         copy=copy,
#    9363         indicator=indicator,
#    9364         validate=validate,
#    9365     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\reshape\merge.py:682, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     678     # stacklevel chosen to be correct when this is reached via pd.merge
#     679     # (and not DataFrame.join)
#     680     warnings.warn(msg, FutureWarning, stacklevel=find_stack_level())
# --> 682 self._validate_specification()
#     684 cross_col = None
#     685 if self.how == "cross":
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\reshape\merge.py:1353, in _MergeOperation._validate_specification(self)
#    1351 common_cols = left_cols.intersection(right_cols)
#    1352 if len(common_cols) == 0:
# -> 1353     raise MergeError(
#    1354         "No common columns to perform merge on. "
#    1355         f"Merge options: left_on={self.left_on}, "
#    1356         f"right_on={self.right_on}, "
#    1357         f"left_index={self.left_index}, "
#    1358         f"right_index={self.right_index}"
#    1359     )
#    1360 if (
#    1361     not left_cols.join(common_cols, how="inner").is_unique
#    1362     or not right_cols.join(common_cols, how="inner").is_unique
#    1363 ):
#    1364     raise MergeError(f"Data columns not unique: {repr(common_cols)}")
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
customer = pd.read_csv("data2/customers.csv")

# %%
#10
no_discount = tx[pd.isnull(tx['discount'])]
have_discount = pd.concat([tx, no_discount], ignore_index=True).drop_duplicates(subset=['customer_id', 'transaction_date', 'ticket_price', 'discount', 'product'], keep=False)
have_discount['discount'] = have_discount['discount'].apply(lambda x: x[:-1]).astype(float)
#have_discount['discount']
have_discount['ticket_price'] = have_discount['ticket_price'] - (have_discount['ticket_price'] * have_discount['discount'] / 100).astype(float)
all = no_discount.merge(have_discount, how = 'outer')
#all = all.merge(customer, how='inner', on='customer_id')
all_merge = all.groupby(['customer_id']).sum(['ticket_price']).merge(customer, how='inner', on='customer_id')
sorted = all_merge.sort_values(by = ['ticket_price'], ascending = False)
print("10.1")
display(sorted[['customer_id', 'ticket_price','address_zip', 'address_state']])
print("10.2\n","top20")
display(sorted[:20])
print("bottom20")
display(sorted[-20:])
# Out:
# 10.1
#                            customer_id  ticket_price  address_zip  \
# 1905  526b5e7734c76a3ff552e5485920e976     2123.3020      11735.0
# 85    040831dd4f47912a7693e829b8e0cf1f     2099.2970      91744.0
# 2706  731d2f33f65b3267ccaec02714a84515     2094.8115      75672.0
# 5504  ea043b69f01503f545a1dfe5681492ba     2082.8155       6095.0
# 3028  811e7d88cb9b9a4e5e8d0231af159f97     1965.8545      46235.0
# ...                                ...           ...          ...
# 2451  6924d615e3676436b83016ffcd3ef8f5       12.3505      65785.0
# 2294  634564d0f115c5273b9d40e62a759cc5       11.7010      11219.0
# 733   20358ce051095b4cb33c4e105120de34       10.4020      98028.0
# 4090  af3065b0f25b301dee4ddcadfc0267ae       10.0000      33321.0
# 3157  8770fd7096dc5a063fcdafd58a99ac77       10.0000      13501.0
#
#      address_state
# 1905            NY
# 85             NaN
# 2706            TX
# 5504            CT
# 3028            IN
# ...            ...
# 2451            MO
# 2294            NY
# 733             WA
# 4090            FL
# 3157            NY
#
# [6027 rows x 4 columns]
# 1905              497 Woodland DR       Farmingdale            NY
# 85             844 Clinton Street         La Puente           NaN
# 2706           378 William Street          Marshall            TX
# 5504                4844 Broad ST           Windsor            CT
# 3028              8357 Park Drive      Indianapolis            IN
# 323              61249 4th Avenue     Half Moon Bay            CA
# 1421        52730 6th Street West  Huntington Beach            CA
# 1419  33829 Delaware Avenue APT B            Urbana            IL
# 1782               476 8th Street          Van Nuys            CA
# 1838              3528 2nd Avenue             Allen            TX
# 2532           7127 Garden Street      Edwardsville           NaN
# 3150              9496 Cedar Lane            Goleta            CA
# 378        1727 Main Street North           Raymore            MO
# 1450              536 11th Street       Walla Walla            WA
# 83                4002 Summit AVE      Baldwin Park            CA
# 2626              5061 Oak Avenue           Abilene            TX
# 2594                82978 1st AVE          Lakewood            CA
# 6020              2138 Lilac Lane             Provo            UT
# 5155        5126 Jefferson Street            Dillon           NaN
# 5199             31581 River Road           Chicago           NaN
#
#       address_zip       region   phone_number   start_date end_date
# 1905      11735.0  midatlantic  (631)760-2984  Apr 01 2010      NaN
# 85        91744.0         west  (323)562-5581   2010/02/03      NaN
# 2706      75672.0    southwest  (903)666-5325   2010/04/07      NaN
# 5504       6095.0     northest  (860)233-9228   2010/04/10      NaN
# 3028      46235.0      midwest  (317)207-6629   2010/08/09      NaN
# 323       94019.0         west  (650)258-9728   2010/08/19      NaN
# 1421      92646.0         west  (714)600-8210  Sep 20 2010      NaN
# 1419      61802.0      midwest  (217)240-8068   2010/10/04      NaN
# 1782      91411.0         west  (818)423-3732   2010/11/11      NaN
# 1838      75002.0    southwest  (214)704-7142   2010/10/30      NaN
# 2532      62025.0      midwest  (618)840-7014   2010/09/06      NaN
# 3150      93117.0         west  (805)553-1019   2010/12/27      NaN
# 378       64083.0      midwest  (816)954-2551   2011/01/22      NaN
# 1450      99362.0    northwest  (509)900-5176   2011/01/03      NaN
# 83        91706.0         west  (714)418-8486   2011/01/15      NaN
# 2626      79602.0    southwest  (325)715-2873   2011/01/27      NaN
# 2594      90715.0         west  (562)897-6755   2011/02/05      NaN
# 6020      84601.0    southwest  (435)517-7990   2011/02/03      NaN
# 5155      80435.0    southwest  (970)751-1345  Jan 18 2011      NaN
# 5199      60634.0      midwest  (773)677-2280   2011/01/28      NaN
# bottom20
#                            customer_id  ticket_price first_name   last_name  \
# 4150  b1bf963e187f8f6aeee2d5d1953e3bf3       13.0000       ELMA     CLOSNER
# 5032  d5d95dfaf3fc90596373fa52248b26ca       13.0000      SONDA     MERDIAN
# 4164  b22755870a81d3cc83857de588dc0ed4       13.0000        DAX        KIRO
# 2683  722c7f93f3ba4d666374e2f9a424c16d       13.0000     MANJIT        PUAA
# 4003  ab69d1f7fa0a581292ced7ebdcb3d705       13.0000       FERN      CHARAN
# 347   1084a0bb76007b3b4b74b93bb6b9b265       13.0000      HAZEL  AUGSBERGER
# 1306  3701cb7c9a740209c887aef442ec4d91       13.0000    VITALIY    CARLBURG
# 3033  8151e79fcda4bf951c296733bd5f8cf6       13.0000    MARYLYN       ELMES
# 3800  a21baed6a18735614222fb0d5e2ec6c9       13.0000    TIMOHTY     FALLERT
# 5897  fa80456cb0f304801ecccefe94cbe751       12.3505      LACIE      BELLIA
# 4652  c65583b15db673038d734323e1779302       12.3505       CARL     YEAREGO
# 4251  b598d6383f8b718238acfc871232425e       12.3505     VALETA        DILS
# 580   1a84e99d4cd320ae76ed28ad54bf60cb       12.3505      MISTI  RUBOYIANES
# 3192  88cfee7c914989f7a26226be7d328a14       12.3505      ARLIN    OGUNDARE
# 2969  7ececa7fe9ec776ca3900ac22b8b2727       12.3505     HELENE       OSATO
# 2451  6924d615e3676436b83016ffcd3ef8f5       12.3505    DONAVON        LODS
# 2294  634564d0f115c5273b9d40e62a759cc5       11.7010   NICHOLAS      ALDAPA
# 733   20358ce051095b4cb33c4e105120de34       10.4020     PEYTON    PLETCHER
# 4090  af3065b0f25b301dee4ddcadfc0267ae       10.0000  ROSEMARIE      KAHLEY
# 3157  8770fd7096dc5a063fcdafd58a99ac77       10.0000       AVIS     DAUGERT
#
#       curent_credit_card                         email  \
# 4150        5.590219e+15             closner97@aol.com
# 5032        5.480463e+15       sonda.merdian@gmail.com
# 4164        4.703830e+15                 dax41@att.net
# 2683        4.246358e+15            manjit37@yahoo.com
# 4003        4.490054e+15                fern24@att.net
# 347         5.478837e+15  hazel.augsberger@outlook.com
# 1306        3.479573e+14            carlburg29@aol.com
# 3033        5.172101e+15       marylyn.elmes@gmail.com
# 3800        4.863498e+15           fallert59@yahoo.com
# 5897        5.395515e+15             lbellia@gmail.com
# 4652        4.945763e+15              cyearego@aol.com
# 4251        5.548502e+15                dils50@att.net
# 580         4.060711e+15       mruboyianes92@gmail.com
# 3192        5.432327e+15    arlin.ogundare68@gmail.com
# 2969        5.380521e+15           osato41@outlook.com
# 2451        4.728300e+15               dlods@gmail.com
# 2294        5.210742e+15           naldapa86@yahoo.com
# 733         5.269101e+15            pletcher70@aol.com
# 4090        4.911387e+15    rosemarie.kahley@gmail.com
# 3157        4.501628e+15          avis.daugert@att.net
#
#        address_street_number     address_city address_state  address_zip  \
# 4150       807 Locust Street          Yonkers            NY      10705.0
# 5032           9505 Olive ST           Fresno            CA      93726.0
# 4164           782 Center ST       Chesapeake            VA      23323.0
# 2683     786 2nd Street East        Henderson            KY      42420.0
# 4003      357 Madison Avenue         Dagsboro            DE      19939.0
# 347   9990 Washington Avenue          Reading            PA      19602.0
# 1306        6073 12th Street        Las Vegas            NV      89103.0
# 3033        26835 Creek Road           Bangor            ME       4401.0
# 3800       35233 Madison AVE      Minneapolis            MN      55433.0
# 5897        8067 Durham Road       Emeryville            CA      94608.0
# 4652         633 Pine Street          Everett            WA      98204.0
# 4251     1072 Academy Street           Geneva            IL      60134.0
# 580         2342 Holly Drive       Birmingham            AL      35214.0
# 3192         7175 Elm Street      Londonderry            NH       3053.0
# 2969        32266 Park Place         Harrison            NJ       7029.0
# 2451          918 Walnut AVE         Stockton            MO      65785.0
# 2294  1816 Main Street South         Brooklyn            NY      11219.0
# 733       1559 George Street          Kenmore            WA      98028.0
# 4090          4197 Linden ST  Fort Lauderdale            FL      33321.0
# 3157     302 Brookside Drive            Utica            NY      13501.0
#
#            region   phone_number   start_date    end_date
# 4150  midatlantic  (914)660-9465   2015/12/07         NaN
# 5032         west  (559)384-8498   2015/12/29         NaN
# 4164        south  (757)580-2585   2015/12/12         NaN
# 2683        south  (270)313-3752   2015/12/08         NaN
# 4003  midatlantic  (302)833-8583   2015/12/16         NaN
# 347   midatlantic  (610)838-1806  Dec 15 2015         NaN
# 1306         west  (702)415-4016   2015/12/04         NaN
# 3033     northest  (207)993-8151  Dec 18 2015         NaN
# 3800      midwest  (612)213-9734  Dec 28 2015         NaN
# 5897         west  (415)407-7378   2015/12/29         NaN
# 4652    northwest  (425)213-9504   2015/12/31         NaN
# 4251      midwest  (630)827-2644   2015/12/21         NaN
# 580         south  (205)838-7858   2015/12/23         NaN
# 3192     northest  (603)428-3293   2015/12/21         NaN
# 2969  midatlantic  (973)524-6290   2015/12/04         NaN
# 2451      midwest  (417)579-1360  Dec 26 2015         NaN
# 2294  midatlantic  (718)687-9548   2015/12/05  2015/12/27
# 733     northwest  (425)567-8298   2015/12/21         NaN
# 4090        south  (954)882-9619   2012/10/13  2012/11/07
# 3157  midatlantic  (315)382-6241  Nov 26 2012  2012/12/23

# %%
#11
all_year = no_discount.merge(have_discount, how = 'outer')
all_year['transaction_date'] = all_year['transaction_date'].apply(lambda x: x[:4]).astype(int)
all_year = all_year.merge(customer, how = 'inner', on = 'customer_id')
#test = all_year.groupby(['address_state']).sum('ticket_price')
pricestate = all_year.groupby(['address_state']).sum(['ticket_price'])

price_state = all_year.merge(pricestate['ticket_price'], how = 'inner', on = 'address_state')
state_group = price_state.groupby(['address_state','transaction_date']).sum(['ticket_price_y'])
#state_group.groupby(['address_state'])
#state_final = all_year.groupby(['address_state']).sum(['ticket_price']).sort_values(by = 'ticket_price')
# Out:
#                transaction_date  ticket_price  curent_credit_card  \
# address_state
# AK                       503475     3556.2730        1.031635e+18
# AL                      3467751    26797.1085        8.116227e+18
# AR                      2801246    22576.8910        6.551702e+18
# AZ                      5838161    44215.2390        1.340753e+19
# CA                     33028049   254467.9190        7.713371e+19
# CO                      4488823    32091.8400        1.067158e+19
# CT                      4084180    33285.0820        9.351127e+18
# DC                       382646     2946.5300        9.561831e+17
# DE                      1363421     9763.9500        3.273060e+18
# FL                     15549694   115732.1150        3.570193e+19
# GA                      8317665    62559.0825        1.919499e+19
# HI                      1723684    12227.8485        3.767162e+18
# IA                      3194023    24104.0425        7.858591e+18
# ID                      1397796    12248.9955        3.566866e+18
# IL                     12504322    99190.1970        2.939992e+19
